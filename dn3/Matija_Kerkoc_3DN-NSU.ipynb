# %% [markdown]
# # Učenje iz kompleksnih podatkovnih tipov
#
# ## 3. Domača naloga pri predmetu NSU
#
# Ukvarjali se bomo z učenjem iz kompleksnih podatkovnih tipov, natančneje iz devetih tabel, ki opisujejo ligo NBA.
#
# Sledeči Jupyter notebook za napovedovanje uporablja **relacijska drevesa**. Z metodami strojnega učenja napovedujemo ali košarkaška ekipa igra v ligi NBA ali ne.

# %%
# imports
from re3py.learners.tree import DecisionTree
from re3py.learners.random_forest import RandomForest
from re3py.learners.boosting import GradientBoosting
from re3py.learners.core.heuristic import *
from re3py.data.data_and_statistics import Dataset
from re3py.ranking.ensemble_ranking import EnsembleRanking
from re3py.utilities.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

import pandas as pd
import math

# %% [markdown]
# Poglejmo si najprej, kako izgledajo naši podatki. Če si pogledamo glavno tabelo TEAMS, vidimo, da je sestavljena iz 95 ekip, vsaka ekipa pa ima 4 atribute (team, location, name in league, ki je ciljna spremenljivka).

# %%
teams = pd.read_csv("dn3/teams.csv", sep="\t") 
teams
# Out:
#    team     location            name league
# 0   ANA      Anaheim          Amigos      A
# 1   AND     Anderson  Duffey Packers      N
# 2   ATL      Atlanta           Hawks      N
# 3   BA1    Baltimore         Bullets      N
# 4   BAL    Baltimore         Bullets      N
# ..  ...          ...             ...    ...
# 90  ID1      Indiana          Pacers      A
# 91  NY1     New York            Nets      A
# 92  SA1  San Antonio           Spurs      A
# 93  ST2    St. Louis         Spirits      A
# 94  TO1      Toronto         Huskies      N
#
# [95 rows x 4 columns]

# %% [markdown]
# Če želimo uporabljati re3py moramo najprej generirati tri datoteke:
# 1. relacije v pravi obliki (basket_opis.txt),
# 2. seznam ciljnih spremenljivk (basket_ciljna.txt) in
# 3. omejitve glede preiskovanja testov (basket.s).
#
# Te datoteke smo pripravili s pomočjo notebooka Priprava_podatkov.ipynb, zato se lahko usmerimo na gradnjo modela.

# %% [markdown]
# ## GRADNJA MODELA

# %% [markdown]
# Poglejmo sedaj, kako dobro delujejo naša relacijska drevesa.

# %%
# datoteke
descriptive = 'basket_opis.txt'
target = 'basket_ciljna.txt'
s_file = 'basket.s'

# zložimo skupaj v naš Dataset
s = Settings(s_file)
d = Dataset(s_file, descriptive, target)

# %% [markdown]
# Naloga od nas zahteva, da vzorčimo stratificirano (po stolpcu 'league'). Metode v paketu re3py imajo že privzeto vgrajeno stratificirano vzorčenje.

# %%
# parametre podamo kot slovar, da jih bomo lažje klicali
tree_params = {'heuristic': HeuristicGini(),
               'max_number_internal_nodes': 100,
               'max_number_atom_tests': 1,
               'allowed_atom_tests': s.get_atom_tests_structured(),
               'allowed_aggregators': s.get_aggregates(),
               'minimal_examples_in_leaf': 1,
               'max_number_of_evaluated_tests_per_node': 1000,
               'max_depth': 20,
               'only_existential': False}

# razdelimo v učno in testno množico
delitev = 0.25
# vzorci_stratificirano(d, delitev)
d_train, d_test = train_test_split(d, test_set=delitev, random_seed=2634)

# %% [markdown]
# Sedaj lahko končno zgradimo ter naučimo naš naključni gozd. Če želimo model tudi shraniti, samo odkomentriramo zadnjo vrstico.

# %%
# naključni gozd
print("Gradim naključni gozd:")
rf = RandomForest(5, **tree_params)  
rf.build(d_train)
rf.print_model('rel_rf.txt')
# rf.save_model('rel_rf.bin')
# Out:
# Gradim naključni gozd:
# Building tree 1
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.10590100288391113
# statistics    : 0.000225067138671875
# test value    : 0.03173422813415527
# eval split    : 0.05303335189819336
# example values: 0.0028421878814697266
# find values   : 0.026587724685668945
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05219388008117676
#
# Building tree 2
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.055047035217285156
# statistics    : 0.0001621246337890625
# test value    : 0.014001131057739258
# eval split    : 0.029992341995239258
# example values: 0.0016219615936279297
# find values   : 0.011121273040771484
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.02958512306213379
#
# Building tree 3
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.049513816833496094
# statistics    : 0.0001468658447265625
# test value    : 0.01052713394165039
# eval split    : 0.02811741828918457
# example values: 0.0014386177062988281
# find values   : 0.007994651794433594
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.027753829956054688
#
# Building tree 4
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.0916600227355957
# statistics    : 0.0002262592315673828
# test value    : 0.013959646224975586
# eval split    : 0.05639052391052246
# example values: 0.0028972625732421875
# find values   : 0.009080886840820312
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05561518669128418
#
# Building tree 5
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.04781317710876465
# statistics    : 0.00014710426330566406
# test value    : 0.008179426193237305
# eval split    : 0.029176950454711914
# example values: 0.0015439987182617188
# find values   : 0.005537986755371094
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.028771638870239258

# %% [markdown]
# Poglejmo si sedaj, kakšna je natančnost našega modela.

# %%
rf.compute_ranking(EnsembleRanking.genie3).print_ranking("genie3_rf.txt")

true_values = [e.target_part for e in d_test.target_data]
predicted_values = [rf.predict(e) for e in d_test.target_data]

# izračunamo natančnost
acc = accuracy_score(true_values, predicted_values)

print('Natančnost modela Naključni gozd je: {0}.\n'.format(acc))
# Out:
# Natančnost modela Naključni gozd je: 1.0.

# %% [markdown]
# Za konec pa nam re3py omogoča tudi izpis najpomembnejših (najkoristnejših) relacij.

# %%
# najpomembnejše relacije
print(rf.compute_ranking(EnsembleRanking.genie3))
# Out:
# Attributes
# coach_season_team[Y,X] :  4.04775e-01 ; iterations: [ 8.52238e-02 ,  7.77006e-02 ,  7.77006e-02 ,  7.71902e-02 ,  8.69599e-02 ]
# team_season_o_asts[X,Y]:  8.15972e-03 ; iterations: [ 8.15972e-03 ,  0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ]
# team_season_won[X,Y]   :  7.54438e-03 ; iterations: [ 0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ,  7.54438e-03 ,  0.00000e+00 ]
#
# Attributes summed
# coach_season_team      :  4.04775e-01 ; iterations: [ 8.52238e-02 ,  7.77006e-02 ,  7.77006e-02 ,  7.71902e-02 ,  8.69599e-02 ]
# team_season_o_asts     :  8.15972e-03 ; iterations: [ 8.15972e-03 ,  0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ]
# team_season_won        :  7.54438e-03 ; iterations: [ 0.00000e+00 ,  0.00000e+00 ,  0.00000e+00 ,  7.54438e-03 ,  0.00000e+00 ]
#
# Aggregators
# count                  :  4.04775e-01 ; iterations: [ 8.52238e-02 ,  7.77006e-02 ,  7.77006e-02 ,  7.71902e-02 ,  8.69599e-02 ]
# sum                    :  1.57041e-02 ; iterations: [ 8.15972e-03 ,  0.00000e+00 ,  0.00000e+00 ,  7.54438e-03 ,  0.00000e+00 ]

# %% [markdown]
# Zanimivo bi bilo videti, kaj se zgodi, ko število dreves v naključnem gozdu povečamo. V našem primeru na 30.

# %%
# naključni gozd
rf30 = RandomForest(30, **tree_params)  
rf30.build(d_train)
rf30.print_model('rel_rf30.txt')
# rf.save_model('rel_rf.bin')

rf30.compute_ranking(EnsembleRanking.genie3).print_ranking("genie3_rf30.txt")

true_values30 = [e.target_part for e in d_test.target_data]
predicted_values30 = [rf30.predict(e) for e in d_test.target_data]
# Out:
# Building tree 1
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.11794090270996094
# statistics    : 0.00024437904357910156
# test value    : 0.01444101333618164
# eval split    : 0.07384800910949707
# example values: 0.0033812522888183594
# find values   : 0.008718252182006836
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.07261133193969727
#
# Building tree 2
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.04933571815490723
# statistics    : 0.00015974044799804688
# test value    : 0.007520437240600586
# eval split    : 0.03150796890258789
# example values: 0.0015094280242919922
# find values   : 0.0048046112060546875
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.031090736389160156
#
# Building tree 3
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.04611468315124512
# statistics    : 0.0001499652862548828
# test value    : 0.0068857669830322266
# eval split    : 0.02814030647277832
# example values: 0.001422882080078125
# find values   : 0.0043010711669921875
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.027715682983398438
#
# Building tree 4
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.09543013572692871
# statistics    : 0.0002617835998535156
# test value    : 0.01536107063293457
# eval split    : 0.05737137794494629
# example values: 0.0028765201568603516
# find values   : 0.008932352066040039
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.0565035343170166
#
# Building tree 5
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.04719996452331543
# statistics    : 0.0001418590545654297
# test value    : 0.006565093994140625
# eval split    : 0.02965831756591797
# example values: 0.001378774642944336
# find values   : 0.004173755645751953
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.02927541732788086
#
# Building tree 6
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.11459994316101074
# statistics    : 0.0002701282501220703
# test value    : 0.017370939254760742
# eval split    : 0.06479930877685547
# example values: 0.003744840621948242
# find values   : 0.010640621185302734
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06367135047912598
#
# Building tree 7
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.09175610542297363
# statistics    : 0.00021696090698242188
# test value    : 0.012353658676147461
# eval split    : 0.05408143997192383
# example values: 0.002637147903442383
# find values   : 0.007721900939941406
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05322527885437012
#
# Building tree 8
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.07360005378723145
# statistics    : 0.00019788742065429688
# test value    : 0.010127782821655273
# eval split    : 0.041792869567871094
# example values: 0.0019338130950927734
# find values   : 0.006674051284790039
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.041116952896118164
#
# Building tree 9
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.07123303413391113
# statistics    : 0.00020623207092285156
# test value    : 0.00960540771484375
# eval split    : 0.04052901268005371
# example values: 0.0018961429595947266
# find values   : 0.006041049957275391
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.03983354568481445
#
# Building tree 10
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.08474421501159668
# statistics    : 0.0003008842468261719
# test value    : 0.011937618255615234
# eval split    : 0.05256009101867676
# example values: 0.002401113510131836
# find values   : 0.0076215267181396484
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05182671546936035
#
# Building tree 11
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.12005996704101562
# statistics    : 0.0003037452697753906
# test value    : 0.016322851181030273
# eval split    : 0.06901836395263672
# example values: 0.003894329071044922
# find values   : 0.009501218795776367
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06793498992919922
#
# Building tree 12
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.11142778396606445
# statistics    : 0.0003314018249511719
# test value    : 0.01486968994140625
# eval split    : 0.06873917579650879
# example values: 0.0029296875
# find values   : 0.009509563446044922
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.06786751747131348
#
# Building tree 13
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.11426401138305664
# statistics    : 0.00026798248291015625
# test value    : 0.014414787292480469
# eval split    : 0.06789565086364746
# example values: 0.002978801727294922
# find values   : 0.009072303771972656
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06683707237243652
#
# Building tree 14
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.11818289756774902
# statistics    : 0.0003390312194824219
# test value    : 0.01679825782775879
# eval split    : 0.06680846214294434
# example values: 0.0033659934997558594
# find values   : 0.010782957077026367
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06561470031738281
#
# Building tree 15
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.07572507858276367
# statistics    : 0.0002086162567138672
# test value    : 0.010356664657592773
# eval split    : 0.043905019760131836
# example values: 0.0020940303802490234
# find values   : 0.006608009338378906
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.04316115379333496
#
# Building tree 16
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
# induce        : 0.08512496948242188
# statistics    : 0.00021910667419433594
# test value    : 0.013204813003540039
# eval split    : 0.05178976058959961
# example values: 0.0025043487548828125
# find values   : 0.008747577667236328
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05104184150695801
#
# Building tree 17
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#         Building node on depth 4
#         Building node on depth 4
#           Building node on depth 5
#           Building node on depth 5
#       Building node on depth 3
# induce        : 0.10852313041687012
# statistics    : 0.000293731689453125
# test value    : 0.012230873107910156
# eval split    : 0.05568981170654297
# example values: 0.0025250911712646484
# find values   : 0.0076787471771240234
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 320
# num t. time   : 0.05455923080444336
#
# Building tree 18
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#         Building node on depth 4
#         Building node on depth 4
#           Building node on depth 5
#           Building node on depth 5
#       Building node on depth 3
# induce        : 0.1414167881011963
# statistics    : 0.0003142356872558594
# test value    : 0.01513528823852539
# eval split    : 0.06788992881774902
# example values: 0.0029349327087402344
# find values   : 0.009774923324584961
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 320
# num t. time   : 0.06635904312133789
#
# Building tree 19
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.0976400375366211
# statistics    : 0.0002493858337402344
# test value    : 0.01339268684387207
# eval split    : 0.05428361892700195
# example values: 0.002553701400756836
# find values   : 0.008885622024536133
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.05318737030029297
#
# Building tree 20
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.05803179740905762
# statistics    : 0.00015783309936523438
# test value    : 0.008431196212768555
# eval split    : 0.03698229789733887
# example values: 0.0016400814056396484
# find values   : 0.004820585250854492
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.03648114204406738
#
# Building tree 21
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.07095694541931152
# statistics    : 0.00019216537475585938
# test value    : 0.010023355484008789
# eval split    : 0.0409393310546875
# example values: 0.0025506019592285156
# find values   : 0.005900144577026367
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.040285587310791016
#
# Building tree 22
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.11520004272460938
# statistics    : 0.00025963783264160156
# test value    : 0.016071319580078125
# eval split    : 0.06907105445861816
# example values: 0.0029942989349365234
# find values   : 0.010644197463989258
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06804418563842773
#
# Building tree 23
#   Building node on depth 1
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.10890531539916992
# statistics    : 0.00025916099548339844
# test value    : 0.015058040618896484
# eval split    : 0.06284809112548828
# example values: 0.003264188766479492
# find values   : 0.00937795639038086
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 240
# num t. time   : 0.06179928779602051
#
# Building tree 24
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.0780038833618164
# statistics    : 0.00022673606872558594
# test value    : 0.010822296142578125
# eval split    : 0.04337048530578613
# example values: 0.0020599365234375
# find values   : 0.0071277618408203125
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.04254484176635742
#
# Building tree 25
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.10307693481445312
# statistics    : 0.00024318695068359375
# test value    : 0.013895511627197266
# eval split    : 0.058075666427612305
# example values: 0.0029425621032714844
# find values   : 0.008746623992919922
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.056672096252441406
#
# Building tree 26
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.08043408393859863
# statistics    : 0.00021529197692871094
# test value    : 0.011313438415527344
# eval split    : 0.043478965759277344
# example values: 0.0020813941955566406
# find values   : 0.00749969482421875
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.04269742965698242
#
# Building tree 27
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#         Building node on depth 4
#         Building node on depth 4
#           Building node on depth 5
#           Building node on depth 5
#       Building node on depth 3
# induce        : 0.11385297775268555
# statistics    : 0.0002658367156982422
# test value    : 0.013907432556152344
# eval split    : 0.05972170829772949
# example values: 0.0026204586029052734
# find values   : 0.008915424346923828
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 320
# num t. time   : 0.058577775955200195
#
# Building tree 28
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
# induce        : 0.04292893409729004
# statistics    : 0.0001380443572998047
# test value    : 0.006082057952880859
# eval split    : 0.02644491195678711
# example values: 0.0012488365173339844
# find values   : 0.0038728713989257812
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 80
# num t. time   : 0.02605414390563965
#
# Building tree 29
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.0694878101348877
# statistics    : 0.00017952919006347656
# test value    : 0.00902247428894043
# eval split    : 0.03894376754760742
# example values: 0.0018434524536132812
# find values   : 0.0057032108306884766
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.03827548027038574
#
# Building tree 30
#   Building node on depth 1
#     Building node on depth 2
#     Building node on depth 2
#       Building node on depth 3
#       Building node on depth 3
# induce        : 0.07227706909179688
# statistics    : 0.0002090930938720703
# test value    : 0.010653972625732422
# eval split    : 0.0413210391998291
# example values: 0.0020754337310791016
# find values   : 0.006996631622314453
# nominal tests : 0
# nom. t. time  : 0
# numeric tests : 160
# num t. time   : 0.04064154624938965

# %%
acc30 = accuracy_score(true_values30, predicted_values30) 

print('Natančnost naključnega gozda s 30 drevesi je: {0}.\n'.format(acc30))
    
# najpomembnejši atributi
print(rf30.compute_ranking(EnsembleRanking.genie3))
# Out:
# Natančnost naključnega gozda s 30 drevesi je: 1.0.
